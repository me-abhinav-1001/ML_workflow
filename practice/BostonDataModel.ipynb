# %% [markdown]
# <a href="https://colab.research.google.com/github/me-abhinav-1001/ML_workflow/blob/main/practice/BostonDataModel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

import tensorflow as tf

# %%
boston_housing_data = tf.keras.datasets.boston_housing.load_data(
    path='boston_housing.npz', test_split=0.2, seed=42
)
# Out:
# ...
# 65536/57026 [==================================] - 0s 0us/step

# %%
X_train = boston_housing_data[0][0]
y_train = boston_housing_data[0][1]
X_test = boston_housing_data[1][0]
y_test = boston_housing_data[1][1]

# %%
len(X_train), len(X_test)
# Out:
# (404, 102)

# %%
len(y_train), len(y_test)
# Out:
# (404, 102)

# %%
X_train
# Out:
# array([[9.1780e-02, 0.0000e+00, 4.0500e+00, ..., 1.6600e+01, 3.9550e+02,
#         9.0400e+00],
#        [5.6440e-02, 4.0000e+01, 6.4100e+00, ..., 1.7600e+01, 3.9690e+02,
#         3.5300e+00],
#        [1.0574e-01, 0.0000e+00, 2.7740e+01, ..., 2.0100e+01, 3.9011e+02,
#         1.8070e+01],
#        ...,
#        [3.0410e-02, 0.0000e+00, 5.1900e+00, ..., 2.0200e+01, 3.9481e+02,
#         1.0560e+01],
#        [5.2058e-01, 0.0000e+00, 6.2000e+00, ..., 1.7400e+01, 3.8845e+02,
#         9.5400e+00],
#        [2.5199e-01, 0.0000e+00, 1.0590e+01, ..., 1.8600e+01, 3.8943e+02,
#         1.8060e+01]])

# %%
# Checkin the shape of our data 
X_train.shape , X_test.shape , y_train.shape , y_test.shape
# Out:
# ((404, 13), (102, 13), (404,), (102,))

# %%
# Building a model

# set random seed
tf.random.set_seed(42)

# Build the model
model_1 = tf.keras.Sequential([
    tf.keras.layers.Dense(200),
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(50),
    tf.keras.layers.Dense(1)
])

# Compile the model
model_1.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(),
                metrics=['mae'])

# Fit the model
history = model_1.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 2s 5ms/step - loss: 49.3536 - mae: 49.3536
# Epoch 2/200
# 13/13 [==============================] - 0s 4ms/step - loss: 16.2946 - mae: 16.2946
# Epoch 3/200
# 13/13 [==============================] - 0s 7ms/step - loss: 9.8599 - mae: 9.8599
# Epoch 4/200
# 13/13 [==============================] - 0s 6ms/step - loss: 8.4735 - mae: 8.4735
# Epoch 5/200
# 13/13 [==============================] - 0s 7ms/step - loss: 7.5552 - mae: 7.5552
# Epoch 6/200
# 13/13 [==============================] - 0s 4ms/step - loss: 6.9606 - mae: 6.9606
# Epoch 7/200
# 13/13 [==============================] - 0s 7ms/step - loss: 7.8716 - mae: 7.8716
# Epoch 8/200
# 13/13 [==============================] - 0s 6ms/step - loss: 6.3488 - mae: 6.3488
# Epoch 9/200
# 13/13 [==============================] - 0s 7ms/step - loss: 6.1402 - mae: 6.1402
# Epoch 10/200
# 13/13 [==============================] - 0s 5ms/step - loss: 8.2886 - mae: 8.2886
# Epoch 11/200
# ...

# %%
# Evaluate the test data
model_1.evaluate(X_test , y_test)
# Out:
# 4/4 [==============================] - 0s 4ms/step - loss: 3.4707 - mae: 3.4707
# [3.470715284347534, 3.470715284347534]

# %%
# Plotting the loss vs epoch graph

pd.DataFrame(history.history).plot()

plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# improving the model
# Building a model

# set random seed
tf.random.set_seed(42)

# Build the model
model_2 = tf.keras.Sequential([
    tf.keras.layers.Dense(200),
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(50),
    tf.keras.layers.Dense(1)
])

# Compile the model
model_2.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=['mae'])

# Fit the model
history = model_2.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 1s 3ms/step - loss: 380.9109 - mae: 380.9109
# Epoch 2/200
# 13/13 [==============================] - 0s 3ms/step - loss: 56.1622 - mae: 56.1622
# Epoch 3/200
# 13/13 [==============================] - 0s 3ms/step - loss: 22.7675 - mae: 22.7675
# Epoch 4/200
# 13/13 [==============================] - 0s 3ms/step - loss: 8.5970 - mae: 8.5970
# Epoch 5/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.9834 - mae: 6.9834
# Epoch 6/200
# 13/13 [==============================] - 0s 3ms/step - loss: 7.0444 - mae: 7.0444
# Epoch 7/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.4461 - mae: 6.4461
# Epoch 8/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.3637 - mae: 6.3637
# Epoch 9/200
# 13/13 [==============================] - 0s 3ms/step - loss: 7.4008 - mae: 7.4008
# Epoch 10/200
# 13/13 [==============================] - 0s 2ms/step - loss: 6.2712 - mae: 6.2712
# ...

# %%
# Let's evaluate on the test data 
model_2.evaluate(X_test , y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4363 - mae: 3.4363
# [3.4362735748291016, 3.4362735748291016]

# %%
# Plotting the loss Vs Epoch 
pd.DataFrame(history.history).plot()
plt.ylabel('loss')
plt.xlabel('epochs')
# Out:
# Text(0.5, 0, 'epochs')

# %%
# improving the model
# Building a model

# set random seed
tf.random.set_seed(42)

# Build the model
model_3 = tf.keras.Sequential([
    tf.keras.layers.Dense(200),
    tf.keras.layers.Dense(200),
    tf.keras.layers.Dense(100),
    tf.keras.layers.Dense(50),
    tf.keras.layers.Dense(1)
])

# Compile the model
model_3.compile(loss=tf.keras.losses.mae,
                optimizer=tf.keras.optimizers.Adam(learning_rate=0.01),
                metrics=['mae'])

# Fit the model
history = model_3.fit(X_train, y_train, epochs=200)
# Out:
# Epoch 1/200
# 13/13 [==============================] - 1s 3ms/step - loss: 529.0533 - mae: 529.0533
# Epoch 2/200
# 13/13 [==============================] - 0s 3ms/step - loss: 63.7598 - mae: 63.7598
# Epoch 3/200
# 13/13 [==============================] - 0s 4ms/step - loss: 14.4907 - mae: 14.4907
# Epoch 4/200
# 13/13 [==============================] - 0s 3ms/step - loss: 8.5861 - mae: 8.5861
# Epoch 5/200
# 13/13 [==============================] - 0s 3ms/step - loss: 7.4985 - mae: 7.4985
# Epoch 6/200
# 13/13 [==============================] - 0s 4ms/step - loss: 7.4442 - mae: 7.4442
# Epoch 7/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.2878 - mae: 6.2878
# Epoch 8/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.6043 - mae: 6.6043
# Epoch 9/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.0916 - mae: 6.0916
# Epoch 10/200
# 13/13 [==============================] - 0s 3ms/step - loss: 6.0570 - mae: 6.0570
# ...

# %%
# Let's evaluate on the test data 
model_3.evaluate(X_test , y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 4.3885 - mae: 4.3885
# [4.388477802276611, 4.388477802276611]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# Hence model_2 performed the best

# %%
model_2.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# ...
#  dense_4 (Dense)             (None, 200)               2800
#
#  dense_5 (Dense)             (None, 100)               20100
#
#  dense_6 (Dense)             (None, 50)                5050
#
#  dense_7 (Dense)             (None, 1)                 51
#
# ...
# Total params: 28,001
# Trainable params: 28,001
# Non-trainable params: 0
# _________________________________________________________________

# %%
model_2.evaluate(X_test , y_test)
# Out:
# 4/4 [==============================] - 0s 3ms/step - loss: 3.4363 - mae: 3.4363
# [3.4362735748291016, 3.4362735748291016]
